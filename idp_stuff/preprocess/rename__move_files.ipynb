# %%
import cv2
import numpy
import glob
from PIL import Image
import os

# %%
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive', force_remount=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
cpt = sum([len(files) for r, d, files in os.walk("/content/drive/My Drive/IDP/20k/3gp/interest_sc")])
print(cpt)
# Out:
# 7780

# %%
#for moving all screenshots to a single folder

import shutil, os, glob
 
def moveAllFilesinDir(srcDir, dstDir):
    # Check if both the are directories
    if os.path.isdir(srcDir) and os.path.isdir(dstDir) :
        # Iterate over all the files in source directory
        for filePath in glob.glob(srcDir + '/*'):
            # Move each file to destination Directory
            shutil.move(filePath, dstDir);
    else:
        print("srcDir & dstDir should be Directories")

# %%
#move higgh quality interest to 'positive'

sourceDir_hq_in = '/content/drive/My Drive/IDP/20k/positive'
destDir_hq_pos =  '/content/drive/My Drive/IDP/20k/4k/interest_resized'
    
moveAllFilesinDir(sourceDir_hq_in,destDir_hq_pos)

# %%
#move high quality non_interest to 'negative'

sourceDir_hq_non = '/content/drive/My Drive/IDP/20k/4k/non_interest_resized'
destDir_hq_ńeg =  '/content/drive/My Drive/IDP/20k/negative'
    
moveAllFilesinDir(sourceDir_hq_non,destDir_hq_ńeg)

# %%
def main(): 
    i = 0
    
    source = "/content/drive/My Drive/IDP/20k/4k/interest_resized/"
      
    for filename in os.listdir(source): 
        dst = "Hostel" + str(i) + ".jpg"
        src = source + filename 
        dst =source + dst 
          
        # rename() function will 
        # rename all the files 
        os.rename(src, dst) 
        i + = 1
  
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %%
print(imagenames_list)
# Out:
# ['/content/drive/My Drive/IDP/20k/positive/7780.png']
