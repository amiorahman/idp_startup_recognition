# %%
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os

file = open('/content/drive/My Drive/idp/20k/4k/interest.txt','r') 
#print(file)

# %%
f = file.read()
#listt = f.split('http://', 1 )

# %%
import csv
with open('/content/drive/My Drive/idp/20k/4k/interest.csv', "w") as file:
    for line in f:
        file.write(line)

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/idp/20k/4k/interest.csv')
df.head()
# Out:
#                homepage_url
# 0     http://activechat.ai/
# 1       http://agilitix.ai/
# 2  http://archanalytics.ai/
# 3      http://canspirit.ai/
# 4       http://lifemesh.ai/

# %%
df.count
# Out:
# <bound method DataFrame.count of                           homepage_url
# 0                http://activechat.ai/
# 1                  http://agilitix.ai/
# 2             http://archanalytics.ai/
# 3                 http://canspirit.ai/
# 4                  http://lifemesh.ai/
# 5                  http://asksavvy.ai/
# 6               http://brandwizard.ai/
# 7                    http://oswald.ai/
# 8      http://exzellenz-management.at/
# 9               http://coresystems.ch/
# 10                 http://junction.ai/
# 11            http://digitalimpact.ai/
# 12                   http://demain.ai/
# 13              http://creativebot.ai/
# 14                     http://truu.ai/
# 15                 http://am-power.de/
# 16               http://ama-adress.de/
# 17                  http://anapath.ch/
# 18                      http://btp.at/
# 19                 http://kidsense.ai/
# 20                http://shelfwise.ai/
# 21                  http://airport.ai/
# ...
